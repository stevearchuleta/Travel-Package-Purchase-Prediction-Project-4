# %% [markdown]
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1.9em; color:#0e92ea"> Steven Gilbert Archuleta
#
# <font color='orange'>
# &nbsp;
#
#
#
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#0e92ea"> Travel Package Purchase Prediction (AIML Project 04)
#
# <font color='orange'>
#
# &nbsp;
#
# Due: 28 AUG 2021 06:30 local time
#
# Sacramento, California (PDT)
#
# &nbsp;
# [My GitHub Link for Project 4](https://github.com/GL-AIML-International/gl-pgp-aiml-ba-uta-intl-may21-stevearchuleta)

# %% [markdown]
# ***

# %% [markdown]
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1m;color:#0e92ea"> Objectives:
#
# <font color=darkblue>
# &nbsp;
#
# 1. Explore and visualize the dataset.
# 2. Predict which customer is more likely to purchase the newly-introduced travel package.
# 3. Which variables are most significant.
# 4. Which segment of customers should be targeted.
#
#
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#0e92ea"> Background and Context:
#
# <font color=darkblue>
#
# &nbsp;
#
#
#
# Herein, I am a Data Scientist for a tourism company named "Visit with us". The Policy Maker of the company wants to enable and establish a viable business model to expand the customer base.
# A viable business model is a central concept that helps explain the existing ways of doing the business and how to change the ways for the benefit of the tourism sector.
# One of the ways to expand the customer base is to introduce a new offering of packages.
# Currently, there are 5 types of packages the company is offering - Basic, Standard, Deluxe, Super Deluxe, King. Looking at the data of the last year, we observed that 18% of the customers purchased the packages.
# However, the marketing cost was quite high because customers were contacted at random without looking at the available information.
# The company is now planning to launch a new product i.e. Wellness Tourism Package. Wellness Tourism is defined as Travel that allows the traveler to maintain, enhance or kick-start a healthy lifestyle, and support or increase one's sense of well-being.
# However, this time company wants to harness the available data of existing and potential customers to make the marketing expenditure more efficient.
# You as a Data Scientist at "Visit with us" travel company have to analyze the customers' data and information to provide recommendations to the Policy Maker and Marketing Team and also build a model to predict the potential customer who is going to purchase the newly introduced travel package.

# %% [markdown]
# ****

# %% [markdown]
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#0e92ea"> Data Dictionary (Raw CSV Data):
#
# <font color=darkblue>
# &nbsp;
#
# This dataset represents key attributes of the "Visit With Us Travel Company" customers.
#
#
# ProdTaken will denote the target/dependent/response variable.
#
#
# The raw csv file contains the following variables:
#
#
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#0e92ea"> Attributes/Series/Features:
#
# <font color=darkblue>
#
# &nbsp;
#
# [CustomerID](#1) -- unique identification number for each customer
#
# <font color=orange>
# 4888 unique integer IDs for 4888 data objects
#
# <br>
# <font color=darkblue>
#
# [ProdTaken](#2) -- whether or not the customer has purchased a travel package; TARGET VARIABLE
#
# <font color=orange>
# 2 unique integer values for 4888 data objects (0: No, 1: Yes)
#
#
# <br>
# <font color=darkblue>
#
# [Age](#3) -- age of the customer
#
# <font color=orange>
# 44 unique float values for 4662 data objects (includes NaN values)
#
# <br>
# <font color=darkblue>
#
# [TypeofContact](#4) -- How the customer was contacted
# <font color=orange>
# 2 unique string values for 4863 data objects (Company Invited, Self Inquiry)
#
# <br>
# <font color=darkblue>
#
# [CityTier](#5) -- 1, 2, or 3 based on population development, facilities development, and living standards
#
# <font color=orange>
# 3 unique ordered/ranked integer values for 4888 data objects (1 > 2 > 3)
#
# <br>
# <font color=darkblue>
#
# [Duration of Pitch](#6) -- duration of sales pitch to customer (in minutes)
#
# <font color=orange>
# 34 unique float values for 4637 data objects (includes NaN values)
#
# <br>
# <font color=darkblue>
#
# [Occupation](#7) -- occupation of customer
#
# <font color=orange>
# 4 unique string values for 4888 data objects (Salaried, Free Lancer, Small Business, Large Business)
#
# <br>
# <font color=darkblue>
#
# [Gender](#8) -- gender of customer
#
# <font color=orange>
# 3 unique string values for 4888 data objects (Male, Female, Fe Male)
#
# <br>
# <font color=darkblue>
#
# [NumberOfPersonVisiting](#9) -- total number of people who plan to travel with the customer
#
# <font color=orange>
# 5 unique floating point values for 4888 data objects (1, 2, 3, 4, 5)
#
# <br>
# <font color=darkblue>
#
# [NumberOfFollowUps](#10) -- number of contacts by sales team after the initial sales pitch
#
# <font color=orange>
# 6 unique floating point values for 4843 data objects
#
# <br>
# <font color=darkblue>
#
# [ProductPitched](#11) -- Product pitched by the salesperson
#
# <font color=orange>
# 6 unique string values for 4888 data objects (Super Deluxe, Deluxe, King, Standard, Basic)
#
# <br>
# <font color=darkblue>
#
# [PreferredPropertyPropertyStar](#12) -- the customer's preferred hotel property rating
#
# <font color=orange>
# 3 unique float values for 4862 data objects (3, 4, 5, NaN)
#
# <br>
# <font color=darkblue>
#
# [MaritalStatus](#13) -- customer's marital status
#
# <font color=orange>
# 4 unique string values for 4888 data objects (Single, Married, Divorced, Unmarried)
#
# <br>
# <font color=darkblue>
#
# [NumberOfTrips](#14) -- customer's average number of trips in a year
#
# <font color=orange>
# 12 integer values for 4748 data objects (1, 2, 3, 4, 5, 6, 7, 8, 19, 20, 21, 22, NaN)
#
# <br>
# <font color=darkblue>
#
# [Passport](#15) -- 0=no, customer does not have a passport; 1=yes, customer has a passport
#
# <font color=orange>
# 2 integer values for 4888 data objects (0, 1)
#
# <br>
# <font color=darkblue>
#
# [PitchSatisfactionScore](#16) -- total number of people who plan to travel with the customer
#
# <font color=orange>
# 5 unique floating point values for 4888 data objects (1, 2, 3, 4, 5)
#
# <br>
# <font color=darkblue>
#
# [OwnCar](#17) -- 0=no, customer does not own a car; 1=yes, customer owns a car
#
# <font color=orange>
# 2 integer values for 4888 data objects (1, 0)
#
# <br>
# <font color=darkblue>
#
# [NumberOfChildrenVisiting](#18) -- total number of children (less than age 5) planning to take the trip with the customer
#
# <font color=orange>
# 4 float values for 4822 data objects (0, 1, 2, 3, NaN)
#
# <br>
# <font color=darkblue>
#
# [Designation](#19) -- designation of the customer in the current organization
#
# <font color=orange>
# 5 string values for 4888 data objects (Executive, VP, AVP, Senior Manager, Manager)
#
# <br>
# <font color=darkblue>
#
# [MonthlyIncome](#20) -- customer's gross monthly income
#
# <font color=orange>
# 2475 float values for 4655 data objects

# %% [markdown]
# ****

# %% [markdown]
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1m;color:#0e92ea"> Problem Defined:
#
# <font color=darkblue>
# &nbsp;
#
# For the new Wellness Tourism Package, how can "Visit With Us" tour company harness their customer database to more efficiently and effectively market the new package and also predict which potential customers might purchase the Wellness Tourism Package?
#
#
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#0e92ea"> Questions:
#
# <font color=darkblue>
#
# &nbsp;
#
# 1. What variables positively correlate to a customer's purchase of a travel package?
# 2. What variables negatively correlate to a customer's purchase of a travel package?
# 3. Which model best fits the data and yields the best predictive outcome?
#
#
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#0e92ea"> Methodology:
#
# <font color=darkblue>
#
# &nbsp;
#
#
#
# * Data Exploration and Data Cleaning
# * Model Building
# * Exploratory Data Analysis (EDA) -- summarize the dataset
# * Data Preprocessing
# * Variable Selection
# * Decision Tree Model
# * Decision Tree Tuned Model
# * Random Forest Estimator
# * Random Forest Tuned Estimator
# * Adaptive Boosting Regressor (Adaboost)
# * Adaboost Tuned
# * Gradient Boost Estimator
# * Gradient Boost Tuned Estimator
# * XGBoost Predictor Model
# * XGBoost Tuned Predictor Model
# * Performance Validation on Test Data
# * Predictions
#
#
# * "ProdTaken" will denote the target/dependent/response variable

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 1. IMPORT LIBRARIES AND PACKAGES

# %%
# Library to suppress warnings or deprecation notes
import warnings

warnings.filterwarnings("ignore")

# This is a python code formatting extention called Black
# %load_ext nb_black

# Libraries to read and manipulate data
import pandas as pd
import numpy as np

# Libraries for data visualization
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns

plt.style.use("ggplot")
sns.set_style("darkgrid")
sns.set()

# Libraries to split data, impute missing values
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# Libraries to import decision tree classifier and different ensemble classifiers
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import GridSearchCV

# Libtune to tune model, get different metric scores
from sklearn import metrics
from sklearn.metrics import (
    confusion_matrix,
    plot_confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
)

# supress numerical display to 2 points of precision in scientific notation
pd.set_option("display.float_format", lambda x: "%.2f" % x)

# remove the limit from the number of displayed columns and rows, so that the entire dataframe is visible and not truncated
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)
# pd.set_option('display.max_rows', None)from sklearn.tree import DecisionTreeClassifier # to build a classification tree
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 2. READ THE DATASET INTO JUPYTER NOTEBOOK

# %%
df = pd.read_excel("Tourism.xlsx", sheet_name="Tourism")

print(
    f"There are {df.shape[0]} personal loan data objects and {df.shape[1]} attributes/features in the Personal Loan Campaign dataset."
)
# Out:
# There are 4888 personal loan data objects and 20 attributes/features in the Personal Loan Campaign dataset.

# %%
# copy data to another varaible to avoid any changes to original/raw dataset
# data = df.copy()

# %% [markdown]
# ***

# %% [markdown]
# ##  <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0e92ea"> OVERVIEW OF DATASET
#
# <font color=orange>
# &nbsp;
#
# 3.  df Data Type     - pandas core frame dataframe
# 4.	Length        - number of data objects
# 5.	Shape           - (rows, columns) (data objects, attributes)
# 6.	Columns         - list of variable attributes
# 7.	List Comprehension  - column-based indexing integers for iloc() function
# 8.  Dictionary Comprehension - column-based key-value pairs
# 9.	Data Types   - value count of datatypes
# 10.	Info          - class, range index, data columns, data types, memory usage
# 11. Duplicated    - sum of duplicated data objects
# 12. Unique Values - number of unique values by column
# 13.	Null         - sum of missing values
# 14.  Head          - first 5 data objects
# 15.  Tail         - last 5 data objects
# 16. Sample(10)   - 10 random data objects
# 17.	Describe        - five number summary of descriptive statistics
# 18. Describe       - include all; summary of categorical and numeric descriptive statistics

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 3. Return the Pandas datatype for the dataframe named "df"

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 4. Return the number of data objects for the dataframe named "df"

# %%
# The raw data has 4888 data objects (travel customers)

len(df)
# Out:
# 4888

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 5. Return the shape of the Pandas dataframe named "df"
#
# <font color=#0e92ea>
#
# ###### OBSERVATION: There are 20 attributes/series/features in the raw used cars dataset

# %%
df.shape
# Out:
# (4888, 20)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 6. Return the column label values for the Pandas dataframe named "df"

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 7. Return a LIST COMPREHENSION that maps an index integer to the column label values for the Pandas dataframe named "df"
#
# NOTE: These index numbers may be used in the iloc() function if/when referencing multiple columns

# %%
# LIST COMPREHENSION - build a reference list of all columns and their indexes  (identify column name by index)

df_col_mapping_list = [f"{c[0]}:{c[1]}" for c in enumerate(df.columns)]
print(df_col_mapping_list)
# Out:
# ['0:CustomerID', '1:ProdTaken', '2:Age', '3:TypeofContact', '4:CityTier', '5:DurationOfPitch', '6:Occupation', '7:Gender', '8:NumberOfPersonVisiting', '9:NumberOfFollowups', '10:ProductPitched', '11:PreferredPropertyStar', '12:MaritalStatus', '13:NumberOfTrips', '14:Passport', '15:PitchSatisfactionScore', '16:OwnCar', '17:NumberOfChildrenVisiting', '18:Designation', '19:MonthlyIncome']

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 8. Return a DICTIONARY COMPREHENSION that maps a key integer to the column label values for the Pandas dataframe named "df"
# NOTE: These key numbers may be used to reference/access particular columns

# %%
# DICTIONARY COMPREHENSION - build a dictionary view of all columns and their indexes  (tool to rename columns, when needed)
df_col_mapping_dict = {c[0]: c[1] for c in enumerate(df.columns)}
print(df_col_mapping_dict)
# Out:
# {0: 'CustomerID', 1: 'ProdTaken', 2: 'Age', 3: 'TypeofContact', 4: 'CityTier', 5: 'DurationOfPitch', 6: 'Occupation', 7: 'Gender', 8: 'NumberOfPersonVisiting', 9: 'NumberOfFollowups', 10: 'ProductPitched', 11: 'PreferredPropertyStar', 12: 'MaritalStatus', 13: 'NumberOfTrips', 14: 'Passport', 15: 'PitchSatisfactionScore', 16: 'OwnCar', 17: 'NumberOfChildrenVisiting', 18: 'Designation', 19: 'MonthlyIncome'}

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 9. Return a count of the datatypes for each of the column label values for the Pandas dataframe named "df"
#
#
# <font color=#0e92ea>
#
# ###### OBSERVATION: There are 7 floating-point-type features, there are 7 int64 integer-type features, and there are 6 object-type features. Gender,  will be transformed into binary categorical variables for analysis and modeling.

# %%
df.dtypes.value_counts()
# Out:
# int64      7
# float64    7
# object     6
# dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 10. Return a table that identifies the following "INFORMATION" about the Pandas dataframe named "df"
#
# <font color=#0e92ea>
#
# #### OBSERVABLE RETURN:
# ######  10a: type of data structure,
# ######  10b: range of data objects,
# ######  10c: number of column label values,
# ######  10d: column index #,
# ######  10e: column label value,
# ######  10f: non-null count,
# ######  10g: datatype for each column label value,
# ######  10h: count of series datatypes,
# ######  10i: memory usage
#
#
# <font color=darkblue>
#
# ###### OBSERVATIONS:
# * Datatypes:14 of the features are continuous numeric;6 are objects
# * Non-Null: Most features have 4888 data objects, but 8 features have missing values
# * Some numeric values will need to be transformed into binary categorical values during the preprocessing stage
# * Object types will be converted to categorical

# %%
# Please read observations above
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
# 10 Drop Customer ID (use pandas index instead)
df.drop(["CustomerID"], axis=1, inplace=True)

# %% [markdown]
# # FIX THE DATATYPES

# %%
# list to convert the categorical features to 'category'
cat_col = [
    "TypeofContact",
    "CityTier",
    "Occupation",
    "Gender",
    "NumberOfPersonVisiting",
    "NumberOfFollowups",
    "ProductPitched",
    "PreferredPropertyStar",
    "MaritalStatus",
    "Passport",
    "PitchSatisfactionScore",
    "OwnCar",
    "NumberOfChildrenVisiting",
    "Designation",
]

# %%
# Printing number of count of each unique value in each column
for column in cat_col:
    print(df[column].value_counts())
    print("-" * 50)
# Out:
# Self Enquiry       3444
# Company Invited    1419
# Name: TypeofContact, dtype: int64
# --------------------------------------------------
# 1    3190
# 3    1500
# 2     198
# Name: CityTier, dtype: int64
# --------------------------------------------------
# Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: Occupation, dtype: int64
# --------------------------------------------------
# Male       2916
# Female     1817
# Fe Male     155
# Name: Gender, dtype: int64
# --------------------------------------------------
# 3    2402
# 2    1418
# 4    1026
# 1      39
# 5       3
# Name: NumberOfPersonVisiting, dtype: int64
# --------------------------------------------------
# 4.00    2068
# 3.00    1466
# 5.00     768
# 2.00     229
# 1.00     176
# 6.00     136
# Name: NumberOfFollowups, dtype: int64
# --------------------------------------------------
# Basic           1842
# Deluxe          1732
# Standard         742
# ...

# %%
# Eliminate the unique value 'Fe Male'
# Replace it with the string 'Female'

df["Gender"] = df["Gender"].str.replace("Fe Male", "Female")
# df[df.replace({"Gender": {"Fe Male": "Female"}})
# df.loc[(df.Gender == "Fe Male"), "Gender"] = "Female"

# %%
# Verification (no more 'Fe Male')

df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# 10
# Covert object data type to category
df[cat_cols] = df[cat_cols].astype("category")

# %%
# 10
# Verification
df.shape
# Out:
# (4888, 19)

# %%
# 10
# Verification
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ProdTaken                 4888 non-null   int64
#  1   Age                       4662 non-null   float64
#  2   TypeofContact             4863 non-null   category
#  3   CityTier                  4888 non-null   category
#  4   DurationOfPitch           4637 non-null   float64
#  5   Occupation                4888 non-null   category
#  6   Gender                    4888 non-null   category
#  7   NumberOfPersonVisiting    4888 non-null   category
#  8   NumberOfFollowups         4843 non-null   category
#  9   ProductPitched            4888 non-null   category
#  10  PreferredPropertyStar     4862 non-null   category
#  11  MaritalStatus             4888 non-null   category
#  12  NumberOfTrips             4748 non-null   float64
# ...

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 11. Return the sum of duplicated data objects in the Pandas dataframe named "df"

# %%
# There are no duplicated data objects
df.duplicated().sum()
# Out:
# 141

# %%
# Drop Duplicate data objects
df.drop_duplicates(inplace=True)

# %%
# Verification
df.duplicated().sum()
# Out:
# 0

# %%
# Verification
df.shape
# Out:
# (4747, 19)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 12. Return the number of unique values for each feature in the Pandas dataframe named "df"
#
# <font color=#0e92ea>
#
# ###### OBSERVATIONS:
# * <span style='color:orange'>BINARY VALUES:  (already encoded as 0s and 1s)</span>  <span style="color:darkblue">ProdTaken, Passport, OwnCar
# * <span style='color:orange'>AGE / DURATION OF PITCH / NUMBER OF TRIPS:  </span> <span style="color:darkblue">There are 44 unique values in age, 34 unique values in Duration Of Pitch, and 12 unique values in Number Of Trips. It may be helpful to BIN these features.
# * <span style='color:orange'>MONTHLY INCOME:  </span>  <span style="color:darkblue">There are 2475 unique values for Monthly Income. It may be helpful to BIN this feature.

# %%
df.nunique()
# Out:
# ProdTaken                      2
# Age                           44
# TypeofContact                  2
# CityTier                       3
# DurationOfPitch               34
# Occupation                     4
# Gender                         2
# NumberOfPersonVisiting         5
# NumberOfFollowups              6
# ProductPitched                 5
# PreferredPropertyStar          3
# MaritalStatus                  4
# NumberOfTrips                 12
# Passport                       2
# PitchSatisfactionScore         5
# OwnCar                         2
# NumberOfChildrenVisiting       4
# Designation                    5
# MonthlyIncome               2475
# dtype: int64

# %% [markdown]
# <font color=orange>
#
# ## 12a. Return some unique values
#
# <font color=#0e92ea>
#
# ###### OBSERVATIONS:
# * <span style='color:orange'>Gender:</span>  <span style="color:darkblue">White space in 'Fe Male' (must change to 'Female')
# * <span style='color:orange'>Customer Designations:</span>  <span style="color:darkblue">Executive, VP, AVP, Senior Manager, Manager
# * <span style='color:orange'>Travel Products:</span>  <span style="color:darkblue">Super Deluxe, Deluxe, King, Standard, Basic
# * <span style='color:orange'>Preferred Property Star:</span>  <span style="color:darkblue">2, 3, 4, NaN (impute after splitting the data)
# * <span style='color:orange'>Number of Trips:</span>  <span style="color:darkblue">1 though 8; then strangely 19,20,20,22; then NaN (impute after splitting the data)
# * <span style='color:orange'>Number of Children Visiting:</span>  <span style="color:darkblue">0, 1, 2, 3, NaN (impute after splitting the data)

# %%
# Return some unique values
# Please read observation above

print("Gender:", df.Gender.unique())
print("\n\n")
print("Number of Persons Visiting:", df.NumberOfPersonVisiting.unique())
print("\n\n")
print("Marital Status:", df.MaritalStatus.unique())
print("\n\n")
print("Occupation:", df.Occupation.unique())
print("\n\n")
print("Designation:", df.Designation.unique())
print("\n\n")
print("Pitch Satisfaction Score:", df.PitchSatisfactionScore.unique())
print("\n\n")
print("Production Pitched:", df.ProductPitched.unique())
print("\n\n")
print("Preferred Property Star:", df.PreferredPropertyStar.unique())
print("\n\n")
print("Number of Trips:", df.NumberOfTrips.unique())
print("\n\n")
print("Number of Children Visiting:", df.NumberOfChildrenVisiting.unique())
print("\n\n")
print("Duration Of Pitch:", df.DurationOfPitch.unique())
print("\n\n")
print("Age:", df.Age.unique())
print("\n\n")
# Out:
# Gender: ['Female', 'Male']
# Categories (2, object): ['Female', 'Male']
#
#
#
# Number of Persons Visiting: [3, 2, 1, 4, 5]
# Categories (5, int64): [1, 2, 3, 4, 5]
#
#
#
# Marital Status: ['Single', 'Divorced', 'Married', 'Unmarried']
# Categories (4, object): ['Divorced', 'Married', 'Single', 'Unmarried']
#
#
#
# Occupation: ['Salaried', 'Free Lancer', 'Small Business', 'Large Business']
# Categories (4, object): ['Free Lancer', 'Large Business', 'Salaried', 'Small Business']
#
#
#
# Designation: ['Manager', 'Executive', 'Senior Manager', 'AVP', 'VP']
# Categories (5, object): ['AVP', 'Executive', 'Manager', 'Senior Manager', 'VP']
#
#
#
# Pitch Satisfaction Score: [2, 3, 5, 4, 1]
# Categories (5, int64): [1, 2, 3, 4, 5]
#
#
#
# Production Pitched: ['Deluxe', 'Basic', 'Standard', 'Super Deluxe', 'King']
# Categories (5, object): ['Basic', 'Deluxe', 'King', 'Standard', 'Super Deluxe']
#
#
#
# Preferred Property Star: [3.00, 4.00, 5.00, NaN]
# ...

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 12. MISSING VALUES:
# ## Return a table that identifies the sum of null values for each attribute in the Pandas dataframe named "df"
#
# <font color=#0e92ea>
#
# ###### OBSERVATIONS:
# * <span style='color:orange'>Age:</span>  <span style="color:darkblue">216 missing values; (I impute with the median value after spitting the data.)
# * <span style='color:orange'>Type of Contact:</span>  <span style="color:darkblue">25 missing values; (valuable info missing--drop these data objects before splitting the data)
# * <span style='color:orange'>Duration of Pitch:</span>  <span style="color:darkblue">246 missing values; (impute with the median value after splitting the data)
# * <span style='color:orange'>Number of Followups:</span>  <span style="color:darkblue">44 missing values; (impute with median value after splitting the data)
# * <span style='color:orange'>Preferred Property Star:</span>  <span style="color:darkblue">26 missing values; (impute with mode value after splitting the data)
# * <span style='color:orange'>Number of Trips:</span>  <span style="color:darkblue">138 missing values; (impute with median value after splitting the data)
# * <span style='color:orange'>Number of Children Visiting:</span>  <span style="color:darkblue">60 missing values; (impute with median value after splitting the data)
# * <span style='color:orange'>Monthly Income:</span>  <span style="color:darkblue">244 missing values; (impute with median value after splitting the data)

# %%
# 12
# Please read observations above
# print true or false for features with missing values

print(df.isnull().any())

# print the numeric total of all missing values

print("\n")
print("Number of total missing values: ", df.isnull().sum().sum())
# Out:
# ProdTaken                   False
# Age                          True
# TypeofContact                True
# CityTier                    False
# DurationOfPitch              True
# Occupation                  False
# Gender                      False
# NumberOfPersonVisiting      False
# NumberOfFollowups            True
# ProductPitched              False
# PreferredPropertyStar        True
# MaritalStatus               False
# NumberOfTrips                True
# Passport                    False
# PitchSatisfactionScore      False
# OwnCar                      False
# NumberOfChildrenVisiting     True
# Designation                 False
# MonthlyIncome                True
# dtype: bool
#
#
# Number of total missing values:  979

# %%
# 12
# Please read observations above
# columns that contain NaN

toBeImputedWithMedian = df.columns[df.isna().any()].tolist()
toBeImputedWithMedian
# Out:
# ['Age',
#  'TypeofContact',
#  'DurationOfPitch',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
# 12
# Please read observations above
# print the number of missing values in each category

df.isna().sum()
# Out:
# ProdTaken                     0
# Age                         216
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             246
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            44
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               138
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     60
# Designation                   0
# MonthlyIncome               224
# dtype: int64

# %%
# 12
# Percentage of missing values in each column
pd.DataFrame(
    data={"% of Missing Values": round(df.isna().sum() / df.isna().count() * 100, 2)}
)
# Out:
#                           % of Missing Values
# ProdTaken                                0.00
# Age                                      4.55
# TypeofContact                            0.53
# CityTier                                 0.00
# DurationOfPitch                          5.18
# Occupation                               0.00
# Gender                                   0.00
# NumberOfPersonVisiting                   0.00
# NumberOfFollowups                        0.93
# ProductPitched                           0.00
# PreferredPropertyStar                    0.55
# MaritalStatus                            0.00
# NumberOfTrips                            2.91
# Passport                                 0.00
# PitchSatisfactionScore                   0.00
# OwnCar                                   0.00
# NumberOfChildrenVisiting                 1.26
# Designation                              0.00
# MonthlyIncome                            4.72

# %%
# 12
# Please read observations above
# Drop the 25 TypeOfContact rows that are NaN
# NOTE: drop NaN prior to splitting the data (note: impute NaN after splitting the data)

df = df.dropna(subset=["TypeofContact"])

# OBSERVATION (important)
# Imagine imputing the mode value for TypeofContact missing data...
# This would unfairly skew the important sales record regarding Company Invited and Self Inquiry
# Sales is about people reaching out to customers. No advantage or disadvantage shall be employed in salesforce data.
# In this case, it is in the best interest of the company's sales team to drop the 25 missing values; rather than impute (do not even proportionally impute)

# %%
# 12
# Verification
df.isna().sum()
# Out:
# ProdTaken                     0
# Age                         216
# TypeofContact                 0
# CityTier                      0
# DurationOfPitch             221
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            44
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               138
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     60
# Designation                   0
# MonthlyIncome               199
# dtype: int64

# %%
len(df)

# OBSERVATION (important)
# Imagine imputing the mode value for TypeofContact missing data...
# This would unfairly skew the important sales record regarding Company Invited and Self Inquiry
# Sales is about people reaching out to customers. No advantage or disadvantage shall be employed in salesforce data.
# In this case, it is in the best interest of the company's sales team to drop the 25 missing values; rather than impute (do not even proportionally impute)
# Out:
# 4722

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 13. Return the first 5 data objects of the Pandas dataframe named "df"

# %%
df.head()
# Out:
#    ProdTaken   Age    TypeofContact CityTier  DurationOfPitch      Occupation  \
# 0          1 41.00     Self Enquiry        3             6.00        Salaried
# 1          0 49.00  Company Invited        1            14.00        Salaried
# 2          1 37.00     Self Enquiry        1             8.00     Free Lancer
# 3          0 33.00  Company Invited        1             9.00        Salaried
# 4          0   NaN     Self Enquiry        1             8.00  Small Business
#
#    Gender NumberOfPersonVisiting NumberOfFollowups ProductPitched  \
# 0  Female                      3              3.00         Deluxe
# 1    Male                      3              4.00         Deluxe
# 2    Male                      3              4.00          Basic
# 3  Female                      2              3.00          Basic
# 4    Male                      2              3.00          Basic
#
#   PreferredPropertyStar MaritalStatus  NumberOfTrips Passport  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 14. Return the last 5 data objects of the Pandas dataframe named "df"

# %%
df.tail()
# Out:
#       ProdTaken   Age    TypeofContact CityTier  DurationOfPitch  \
# 4883          1 49.00     Self Enquiry        3             9.00
# 4884          1 28.00  Company Invited        1            31.00
# 4885          1 52.00     Self Enquiry        3            17.00
# 4886          1 19.00     Self Enquiry        3            16.00
# 4887          1 36.00     Self Enquiry        1            14.00
#
#           Occupation  Gender NumberOfPersonVisiting NumberOfFollowups  \
# 4883  Small Business    Male                      3              5.00
# 4884        Salaried    Male                      4              5.00
# 4885        Salaried  Female                      4              4.00
# 4886  Small Business    Male                      3              4.00
# 4887        Salaried    Male                      4              4.00
#
#      ProductPitched PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 4883         Deluxe                  4.00     Unmarried           2.00
# ...

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 15. Return a random sample of 10 data objects of the Pandas dataframe named "df"

# %%
df.sample(10)
# Out:
#       ProdTaken   Age    TypeofContact CityTier  DurationOfPitch  \
# 1870          0 39.00  Company Invited        1             6.00
# 3653          0 61.00     Self Enquiry        1             7.00
# 2518          0 37.00     Self Enquiry        1            13.00
# 2222          1 36.00     Self Enquiry        1            22.00
# 2602          0 41.00     Self Enquiry        3            11.00
# 2439          1 48.00     Self Enquiry        3             8.00
# 4239          0 32.00  Company Invited        1            14.00
# 4349          1 34.00     Self Enquiry        1            22.00
# 1943          0 49.00     Self Enquiry        1            24.00
# 3336          1 20.00  Company Invited        1            17.00
#
#           Occupation  Gender NumberOfPersonVisiting NumberOfFollowups  \
# 1870        Salaried    Male                      2              3.00
# 3653  Small Business    Male                      4              6.00
# ...

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 16. Return a table of aggragated "five number summary" values for the numeric attributes in the Pandas dataframe named "df"
#
# <font color=#0e92ea>
#
# ###### OBSERVATIONS:
# * <span style='color:orange'>Age:</span> min=18, max=61, mean=37.63, median=36;  <span style="color:darkblue"> mean > median; slightly right skewed; no age outliers
# * <span style='color:orange'>Number of Trips:</span> min=1, max=22, mean=3.23, median=3; <span style="color:darkblue">There is a value of 22 trips as the minimum value, which seems like an odd outlier; mean and median are basically the same; 75% of customers take 4 trips (or less) per year.
# * <span style='color:orange'>Monthly Income:</span> min=1000, max=98,678; mean=23,602.24, median=22,311.00<span style="color:darkblue"> mean > median, slightly right skewed; there are some income outliers
# * <span style='color:orange'>Duration Of Pitch:</span> min=5, max=127; mean=15.51, median=13; <span style="color:darkblue"> mean > mean, right skew; 75% of initial sales pitches were less than 20 minutes; there is a max outlier of 2 hours and 7 minutes.
# * <span style='color:orange'>Number Of FollowUps:</span> min=1, max=6; mean=3.71, median=4; <span style="color:darkblue">mean less than median, left skewed; on average, most customers received almost 4 followup calls
# * <span style='color:orange'>Pitch Satisfaction Score:</span> min=1, max=5; mean=3.05, median=3<span style="color:darkblue">The median and mean are the same:a score of 3; all 4888 customers gave a score (which seems exceptional)
# * <span style='color:orange'>Number Of Persons Visiting:</span> min=1, max=5; mean=2.91 median=3<span style="color:darkblue">The median and mean are basically the same; 75% of customers travel with 3 or less persons

# %%
# Describe Continuous Numeric Features
# Please read the observations that are listed above

describeContinuous = set(df.columns) - {
    "CityTier",
    "PreferredPropertyStar",
    "OwnCar",
    "CustomerID",
    "Passport",
    "CustomerID",
    "TypeOfContact",
    "Occupation",
    "Gender",
    "ProductPitched",
    "NumberOfPersonVisiting",
    "NumberOfFollowups",
    "MaritalStatus",
    "PitchSatisfactionScore",
    "NumberOfChildrenVisiting",
    "Designation",
}
df1 = df[list(describeContinuous)]
df1.describe().round(2)
# Out:
#        DurationOfPitch     Age  NumberOfTrips  MonthlyIncome  ProdTaken
# count          4501.00 4506.00        4584.00        4523.00    4722.00
# mean             15.51   37.63           3.23       23602.24       0.19
# std               8.54    9.33           1.85        5385.50       0.39
# min               5.00   18.00           1.00        1000.00       0.00
# 25%               9.00   31.00           2.00       20337.00       0.00
# 50%              13.00   36.00           3.00       22311.00       0.00
# 75%              20.00   44.00           4.00       25535.50       0.00
# max             127.00   61.00          22.00       98678.00       1.00

# %%
# Transposed
# Please read the observations that are listed above

df.describe().T
# Out:
#                   count     mean     std     min      25%      50%      75%  \
# ProdTaken       4722.00     0.19    0.39    0.00     0.00     0.00     0.00
# Age             4506.00    37.63    9.33   18.00    31.00    36.00    44.00
# DurationOfPitch 4501.00    15.51    8.54    5.00     9.00    13.00    20.00
# NumberOfTrips   4584.00     3.23    1.85    1.00     2.00     3.00     4.00
# MonthlyIncome   4523.00 23602.24 5385.50 1000.00 20337.00 22311.00 25535.50
#
#                      max
# ProdTaken           1.00
# Age                61.00
# DurationOfPitch   127.00
# NumberOfTrips      22.00
# MonthlyIncome   98678.00

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 17. Return the value count for each numeric feature in the Pandas dataframe named "df"
#
# <font color=#0e92ea>
#
# ###### OBSERVATIONS:
# * <span style='color:orange'>ProdTaken:</span> 891 Yes, 3831 No <span style="color:darkblue">18.86% of customer base purchased travel products in the past
# * <span style='color:orange'>City Tier:</span> Tier_1 = 3081; Tier_2 = 188; Tier_3 = 1453 <span style="color:darkblue">65.24% of customers (3081/4722) live in top ranked Tier 1 areas
#
#
# * <span style='color:orange'>Duration Of Pitch:</span> 126 (1) and 127 (1) are outliers <span style="color:darkblue">Keep the two (2) rows with these two (2) outlier values because sales people could have spoken for 2-plus hours to convince a customer
# * <span style='color:orange'>Number Of Trips:</span> 19 (1), 20 (1), 21 (1), and 22 (1) are outliers <span style="color:darkblue">Drop the four (4) rows with these four (4) outlier values

# %%
# Numeric Value Counts (subtract out objects)
# See observations above

numValues = set(df.columns) - {
    "TypeOfContact",
    "Occupation",
    "Gender",
    "ProductPitched",
    "MaritalStatus",
    "Designation",
}

for iterator in describeContinuous:
    print("The unique values in", iterator, "are:")
    print(df[iterator].value_counts().sort_values(ascending=False))
    print("\n")
    print("=" * 40)
    print("\n")

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 18. Return the value count for each categorical feature in the Pandas dataframe named "df"
#
# <font color=#0e92ea>
#
# ###### OBSERVATIONS:
# * <span style='color:orange'>Designation:</span> Executive = 1790, Manager = 1669, VP = 225 <span style="color:darkblue">73.2% of customer base are either Executives or Managers; less than 5% are VPs.
# * <span style='color:orange'>Gender:</span> Male = 2820, Female = 1902 <span style="color:darkblue">Males make up almost 60% of the customer base
# * <span style='color:orange'>ProductPitched:</span> Basic = 1790, Deluxe = 1669, King = 225 <span style="color:darkblue">73.2% of customer buy Basic or Deluxe packages; less than 5% buy King.
# * <span style='color:orange'>Preferred Property Star:</span> 3 star: 2886 <span style="color:darkblue">61.1% of customers prefer a 3-star property
# * <span style='color:orange'>Marital Status:</span> Married = 2264 <span style="color:darkblue">47.5% of customer are married
# * <span style='color:orange'>Type Of Contact:</span> Self Inquiry: 3350 <span style="color:darkblue">70.9% of customers contacted the travel company on their own
#
#
# ###### OBSERVATIONS:
# * <span style='color:orange'>**EXACT SAME VALUES** Designation and Products Pitched:</span> These two columns each have five (5) different categories, but each category for both columns have the same five values (1790, 1669, 714, 324, and 225).  <span style="color:darkblue">There is definitely an error in the dataset

# %%
# Categorical Value Counts
# See observations above

catValues = set(df.columns) - {
    "ProdTaken",
    "Age",
    "DurationOfPitch",
    "NumberOfTrips",
    "MonthlyIncome",
}

for iterator in catValues:
    print("The unique values in", iterator, "are:")
    print(df[iterator].value_counts().sort_values(ascending=False))
    print("\n")
    print("=" * 40)
    print("\n")
# Out:
# The unique values in CityTier are:
# 1    3081
# 3    1453
# 2     188
# Name: CityTier, dtype: int64
#
#
# ...
#
#
# The unique values in NumberOfPersonVisiting are:
# 3    2328
# 2    1347
# 4    1009
# 1      35
# 5       3
# Name: NumberOfPersonVisiting, dtype: int64
#
#
# ...
#
#
# The unique values in OwnCar are:
# 1    2918
# 0    1804
# Name: OwnCar, dtype: int64
#
#
# ...
#
#
# The unique values in ProductPitched are:
# Basic           1790
# Deluxe          1669
# Standard         714
# Super Deluxe     324
# King             225
# Name: ProductPitched, dtype: int64
#
#
# ...
#
#
# The unique values in Gender are:
# Male      2820
# Female    1902
# Name: Gender, dtype: int64
#
#
# ...
#
#
# The unique values in Passport are:
# 0    3347
# 1    1375
# Name: Passport, dtype: int64
#
#
# ...
#
#
# The unique values in NumberOfChildrenVisiting are:
# 1.0    2003
# 2.0    1302
# 0.0    1033
# 3.0     324
# Name: NumberOfChildrenVisiting, dtype: int64
#
#
# ...
#
#
# The unique values in TypeofContact are:
# ...

# %%
# 18
# Transposed Summary of categorical
# OBSERVATIONS:  This is A FUN WAY of articulating the top -- perhaps "ideal" -- customer:
# "A married male executive on a salary calls into the travel company and purchases a basic package."

df.describe(include=["category"]).T
# Out:
#                            count unique           top    freq
# TypeofContact               4722      2  Self Enquiry    3350
# CityTier                    4722      3             1    3081
# Occupation                  4722      4      Salaried    2288
# Gender                      4722      2          Male    2820
# NumberOfPersonVisiting      4722      5             3    2328
# NumberOfFollowups        4678.00   6.00          4.00 1992.00
# ProductPitched              4722      5         Basic    1790
# PreferredPropertyStar    4696.00   3.00          3.00 2886.00
# MaritalStatus               4722      4       Married    2264
# Passport                    4722      2             0    3347
# PitchSatisfactionScore      4722      5             3    1415
# OwnCar                      4722      2             1    2918
# NumberOfChildrenVisiting 4662.00   4.00          1.00 2003.00
# Designation                 4722      5     Executive    1790

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 19. Return the count for Product Taken (the target variable). How many customers purchased a travel package in the past?
#
# <font color=#0e92ea>
#
# ###### OBSERVATIONS:
# * <span style='color:orange'>**BAR PLOT COUNT** Experience:</span> 0=No, 1=Yes
#
# <span style="color:darkblue">3831 No, **891 Yes**
#
# <span style="color:darkblue">81.13% No, **18.87% Yes**

# %%
# Counts for target variable
# Count for the last campain: Did this customer accept the personal loan offered?

print(df["ProdTaken"].value_counts(dropna=False))
print("\n")
print(df["ProdTaken"].value_counts(normalize=True) * 100)
# Out:
# 0    3831
# 1     891
# Name: ProdTaken, dtype: int64
#
#
# 0   81.13
# 1   18.87
# Name: ProdTaken, dtype: float64

# %%
# Bar plot for the zero (0=no) class and the one (1=yes) for the target variable

count = df["ProdTaken"].value_counts()
count.plot(kind="bar", title="Count of ProdTaken")
# Out:
# <AxesSubplot:title={'center':'Count of ProdTaken'}>

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 19.5. Return a table of the mean Monthly Income by the customer's Designation

# %%
df.groupby("Designation").mean()["MonthlyIncome"].sort_values(ascending=False)
# Out:
# Designation
# VP               35880.43
# AVP              32232.49
# Senior Manager   26664.75
# Manager          22659.49
# Executive        19940.01
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 20. Return a histogram and boxplot for seven (7) numeric series attributes for the Pandas dataframe named "df"
#
#
# <font color=#0e92ea>
#
#
# #### 20a. MonthlyIncome -- <span style='color:darkblue'>OBSERVATION: mean > median, slightly right skewed; there are some income outliers. Most income values range between 20,000 and 40,000</span>
# #### 20b. Age -- <span style='color:darkblue'>OBSERVATION: no age outliers; customers appears to be a good (non-skewed) normal distribution; mean age = 37.6.</span>
# #### 20c. Number Of Trips -- <span style='color:darkblue'>OBSERVATION: mean > median; There are four (4) outlier values of 19,20,21, and 22 trips (those outliers can be replaced with the median, which is 3); 75% of customers take 4 trips (or less) per year.</span>
# #### 20d. Number Of Persons Visiting-- <span style='color:darkblue'>OBSERVATION: The median and mean are basically the same; 75% of customers travel with 3 or less persons</span>
# #### 20e. Duration of Pitch -- <span style='color:darkblue'>OBSERVATION:  mean > mean, right skew; 75% of initial sales pitches were less than 20 minutes; mean = ~13.5 minutes; there are two (2) outlier values of over 2 hours long (those rows can remain or be dropped -- Perhaps a sales call became very friendly, so I shall keep them.)</span>
# #### 20f. Number Of Followups -- <span style='color:darkblue'>OBSERVATION: mean less than median, left skewed; on average, most customers received almost 4 followup calls</span>
# #### 20g. Pitch Satisfaction Score -- <span style='color:darkblue'>OBSERVATION: The median and mean are the same:a score of 3; all customers gave a score (which seems exceptional)</span>

# %%
def histogram_boxplot(data, feature, figsize=(15, 10), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (15,10))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21a. MonthlyIncome

# %%
# 21a
# Please read the observations above for 21a

histogram_boxplot(df, "MonthlyIncome")

# %%
# 21a
# Return extreme values for income
df[(df.MonthlyIncome > 40000) | (df.MonthlyIncome < 12000)]
# Out:
#       ProdTaken   Age TypeofContact CityTier  DurationOfPitch      Occupation  \
# 38            0 36.00  Self Enquiry        1            11.00        Salaried
# 142           0 38.00  Self Enquiry        1             9.00  Large Business
# 2482          0 37.00  Self Enquiry        1            12.00        Salaried
# 2586          0 39.00  Self Enquiry        1            10.00  Large Business
#
#       Gender NumberOfPersonVisiting NumberOfFollowups ProductPitched  \
# 38    Female                      2              4.00          Basic
# 142   Female                      2              3.00         Deluxe
# 2482  Female                      3              5.00          Basic
# 2586  Female                      3              4.00         Deluxe
#
#      PreferredPropertyStar MaritalStatus  NumberOfTrips Passport  \
# 38                     NaN      Divorced           1.00        1
# 142                   3.00        Single           4.00        1
# ...

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21b. Age

# %%
# 21b
# Please read the observations above for 21b

histogram_boxplot(df, "Age")

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21c. Number Of Trips

# %%
# 21c
# Please read the observations above for 21c

histogram_boxplot(df, "NumberOfTrips")

# %%
# NumberOfTrips Value Counts (normalized)

df.NumberOfTrips.value_counts(normalize=True)
# Out:
# 2.00    0.31
# 3.00    0.23
# 1.00    0.13
# 4.00    0.10
# 5.00    0.10
# 6.00    0.07
# 7.00    0.05
# 8.00    0.02
# 19.00   0.00
# 21.00   0.00
# 20.00   0.00
# 22.00   0.00
# Name: NumberOfTrips, dtype: float64

# %%
# NumberOfTrips Outliers

# df[df["NumberOfTrips"] > 8]["NumberOfTrips"].unique()

# %%
# IMPUTE LATER... after splitting... not right here

# correct outliers with median (which seem to be data input errors)

# df["NumberOfTrips"].replace(19.0, 3, inplace=True)
# df["NumberOfTrips"].replace(20.0, 3, inplace=True)
# df["NumberOfTrips"].replace(21.0, 3, inplace=True)
# df["NumberOfTrips"].replace(22.0, 3, inplace=True)

# %%
# Verification

# df["NumberOfTrips"].describe()

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21e. Duration Of Sales Pitch

# %%
# 21e
# Please read the observations above for 21e
histogram_boxplot(df, "DurationOfPitch")

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 21. Estimator of the Cumulative Distribution Function: The ECDF plots a feature of the data from least to greatest, in order, and it visualizes the whole feature as if were distributed across the data set.
#
# <font color=#0e92ea>
#
# ###### OBSERVATIONS:
# * <span style='color:orange'>Monthly Income and Duration of Pitch</span> Follow the same cumulative distribution curve from least to greatest.
# * <span style='color:orange'>Age</span> About 60% of the customers age 35 purchase a travel package.

# %%
def ecdf(df_arr):
    # number of data points
    n = len(df_arr)
    xvals = np.sort(df_arr)
    yvals = np.arange(1, n + 1) / n
    return xvals, yvals


for var in ["MonthlyIncome", "Age", "DurationOfPitch"]:
    tmpx, tmpy = ecdf(df.loc[df["ProdTaken"] == 0, var])
    t1, t2 = ecdf(df.loc[df["ProdTaken"] == 1, var])
    _ = plt.plot(tmpx, tmpy, marker=".", linestyle="none", label="Not Purchased")
    _ = plt.plot(t1, t2, marker=".", linestyle="none", label="Purchased")
    _ = plt.legend(("Not Purchased", "Purchased"), loc="lower right")
    _ = plt.xlabel(var)
    _ = plt.ylabel("ECDF")
    plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 22. Return barplot for eleven (11) categorical series attributes for the Pandas dataframe named "df"
#
#
# <font color=#0e92ea>
#
#
# #### 22a. ProdTaken -- <span style='color:darkblue'>OBSERVATION: 81% did not purchase a travel package product.</span>
# #### 22b. TypeOfContact -- <span style='color:darkblue'>OBSERVATION: Only 29.1% were contacted by company sales team.</span>
# #### 22c. CityTier -- <span style='color:darkblue'>OBSERVATION: Tier 2 area makes up only 4% of customer living region.</span>
# #### 22d. Occupation -- <span style='color:darkblue'>OBSERVATION: Freelancers make up 0% of customers.</span>
# #### 22e. Gender -- <span style='color:darkblue'>OBSERVATION:  Only 40% of customers are women.</span>
# #### 22f. PreferredPropertyStar -- <span style='color:darkblue'>OBSERVATION: 3-star property preferences far outnumber 4-star and 5-star, combined.</span>
# #### 22g. MaritalStatus -- <span style='color:darkblue'>OBSERVATION: Only 13.6 are unmarried.</span>
# #### 22h. Passport -- <span style='color:darkblue'>OBSERVATION: Only 29.1% of customers have a passport.</span>
# #### 22i. OwnCar -- <span style='color:darkblue'>OBSERVATION:  38.2% of customers do not own a car.</span>
# #### 22j. Designation -- <span style='color:darkblue'>OBSERVATION: Only 11.7% are either VP or AVP.</span>
# #### 22k. ProductPitched -- <span style='color:darkblue'>OBSERVATION: 73.2% of pitches were for basic or deluxe.</span>
#
#
# ***

# %%
# function to create labeled barplots


def labeled_barplot(df, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(df[feature])  # length of the column
    count = df[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=df,
        x=feature,
        palette="Paired",
        order=df[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21a. ProdTaken

# %%
labeled_barplot(df, "ProdTaken", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21b. TypeofContact

# %%
labeled_barplot(df, "TypeofContact", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21c. CityTier

# %%
labeled_barplot(df, "CityTier", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21d. Occupation

# %%
labeled_barplot(df, "Occupation", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21e. Gender

# %%
labeled_barplot(df, "Gender", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21f. PreferredPropertyStar

# %%
labeled_barplot(df, "PreferredPropertyStar", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21g. MaritalStatus

# %%
labeled_barplot(df, "MaritalStatus", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 21h. Passport

# %%
labeled_barplot(df, "Passport", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 22i. OwnCar

# %%
labeled_barplot(df, "OwnCar", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 22j. Designation

# %%
labeled_barplot(df, "Designation", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 22k. ProductPitched

# %%
labeled_barplot(df, "ProductPitched", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 22l. Number Of Persons Visiting

# %%
# 22l
# Please read the observations above for 22l
labeled_barplot(df, "NumberOfPersonVisiting", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 22m. Number Of Followups

# %%
# 22m
# Please read the observations above for 22m
labeled_barplot(df, "NumberOfFollowups", perc=True)

# %% [markdown]
# <font color=#0e92ea>
#
#
# #### 22n. Pitch Satisfaction Score

# %%
# 22n
# Please read the observations above for 22n
labeled_barplot(df, "PitchSatisfactionScore", perc=True)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 23. Return the pairwise correlation of all columns as well as a heatmap for the dataframe
#
# ###### OBSERVATIONS:
# * <span style='color:#0e92ea'>Number of Persons Visiting & Number Of Children Visiting:</span> <span style='color:darkblue'>Number Of Persons Visiting and Number Of Children Visiting are moderately correlated (.61)</span>
# * <span style='color:#0e92ea'>Age & Monthly Income:</span> <span style='color:darkblue'>With age comes income; these two are 0.47 correlated</span>

# %%
df.corr()
# Out:
#                  ProdTaken   Age  DurationOfPitch  NumberOfTrips  \
# ProdTaken             1.00 -0.15             0.07           0.02
# Age                  -0.15  1.00            -0.01           0.18
# DurationOfPitch       0.07 -0.01             1.00           0.01
# NumberOfTrips         0.02  0.18             0.01           1.00
# MonthlyIncome        -0.13  0.47            -0.01           0.14
#
#                  MonthlyIncome
# ProdTaken                -0.13
# Age                       0.47
# DurationOfPitch          -0.01
# NumberOfTrips             0.14
# MonthlyIncome             1.00

# %%
plt.figure(figsize=(15, 7))
corr = df.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral", mask=mask)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 24. Return a pairplot for for the dataframe
#
# ###### OBSERVATIONS:
# * <span style='color:#0e92ea'>ProdTaken:</span> <span style='color:darkblue'>Herein, the orange dots represent the distribution for Travel Package Products Taken.</span>
# * <span style='color:#0e92ea'>ProdTaken:</span> <span style='color:darkblue'>Herein, there is no clear distinction within the distribution of variables for customers who have taken the product and those who have not taken the product.</span>
# * <span style='color:#0e92ea'>Age & Duration of Pitch:</span> <span style='color:darkblue'>The sales pitch stays within a tight range (less than 35 minutes) no matter what the customer's age is.</span>
# * <span style='color:#0e92ea'>Age & Income:</span> <span style='color:darkblue'>Income levels increase until age 30 then level out.</span>

# %%
# Please read observations above
sns.pairplot(data=df, hue="ProdTaken")
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 25. Return a boxplot to visualize continuous features versus Travel Package Product Taken
#
# ###### OBSERVATIONS:
# * <span style='color:#0e92ea'>Age:</span> <span style='color:darkblue'>Median Age for those who purchase tickets is 38, slightly lower than those who do not.</span>

# %%
cols = df[
    [
        "Age",
        "NumberOfPersonVisiting",
        "NumberOfTrips",
        "NumberOfChildrenVisiting",
        "MonthlyIncome",
        "PitchSatisfactionScore",
    ]
].columns.tolist()
plt.figure(figsize=(12, 7))

for i, variable in enumerate(cols):
    plt.subplot(3, 2, i + 1)
    sns.boxplot(df["ProdTaken"], df[variable], palette="PuBu")
    plt.tight_layout()
    plt.title(variable)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 26. Return a stacked barplot to visualize categorical features versus Travel Package Product Taken
#
# ###### OBSERVATIONS:
# * <span style='color:#0e92ea'>ProdTaken vs. TypeofContact:</span> <span style='color:darkblue'>By a slight margin, those who were contacted by a company sale person were more likely to purchase a travel package.</span>
# * <span style='color:#0e92ea'>ProdTaken vs. CityTier:</span> <span style='color:darkblue'>Tier 1 purchased more overall packages, but Tier 3 had a higher percentage of purchasers.</span>
# * <span style='color:#0e92ea'>ProdTaken vs. Occupation:</span> <span style='color:darkblue'>Those who work for large businesses have a higher percentage of travel purchases than any other occupation.</span>
# * <span style='color:#0e92ea'>ProdTaken vs. Gender:</span> <span style='color:darkblue'>Men buy more packages overall, but in terms of percentages, there is not much of a split between males and females.</span>
# * <span style='color:#0e92ea'>ProdTaken vs. Preferred Property Star:</span> <span style='color:darkblue'>5-star properties sell at an overall lower gross number, however those who do prefer 5-star properties tend to purchase at a higher percentage rate: ~25%.</span>
# * <span style='color:#0e92ea'>ProdTaken vs. MaritalStatus:</span> <span style='color:darkblue'>Although married customers buy more, single customers buy at a higher percentage rate: ~35%</span>
# * <span style='color:#0e92ea'>ProdTaken vs. Passport:</span> <span style='color:darkblue'>38% vs 10%, in terms of those customers with passports who purchase travel packages. Only 10% without passports tend to purchase a travel package.</span>
# * <span style='color:#0e92ea'>ProdTaken vs. OwnCar:</span> <span style='color:darkblue'>Car ownership does not seem to make a difference either way; both percentages are basically the same.</span>
# * <span style='color:#0e92ea'>ProdTaken vs. Designation:</span> <span style='color:darkblue'>Executives purchase travel packages at a 30% rate, which is the highest for any designation.</span>
# * <span style='color:#0e92ea'>ProdTaken vs. ProductPitched:</span> <span style='color:darkblue'>30% sales rate for the Basic package, while super deluxe is very difficult to pitch at 5%.</span>

# %%
# function to plot stacked bar chart


def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left",
        frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
stacked_barplot(df, "TypeofContact", "ProdTaken")
# Out:
# ProdTaken           0    1   All
# TypeofContact
# All              3831  891  4722
# Self Enquiry     2753  597  3350
# Company Invited  1078  294  1372
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(df, "CityTier", "ProdTaken")
# Out:
# ProdTaken     0    1   All
# CityTier
# All        3831  891  4722
# 1          2577  504  3081
# 3          1108  345  1453
# 2           146   42   188
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(df, "Occupation", "ProdTaken")
# Out:
# ProdTaken          0    1   All
# Occupation
# All             3831  891  4722
# Salaried        1889  399  2288
# Small Business  1636  372  2008
# Large Business   306  118   424
# Free Lancer        0    2     2
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(df, "Gender", "ProdTaken")
# Out:
# ProdTaken     0    1   All
# Gender
# All        3831  891  4722
# Male       2261  559  2820
# Female     1570  332  1902
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(df, "PreferredPropertyStar", "ProdTaken")
# Out:
# ProdTaken                 0    1   All
# PreferredPropertyStar
# All                    3811  885  4696
# 3.0                    2418  468  2886
# 5.0                     692  241   933
# 4.0                     701  176   877
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(df, "MaritalStatus", "ProdTaken")
# Out:
# ProdTaken         0    1   All
# MaritalStatus
# All            3831  891  4722
# Married        1950  314  2264
# Single          576  295   871
# Unmarried       484  159   643
# Divorced        821  123   944
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(df, "Passport", "ProdTaken")
# Out:
# ProdTaken     0    1   All
# Passport
# All        3831  891  4722
# 1           895  480  1375
# 0          2936  411  3347
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(df, "OwnCar", "ProdTaken")
# Out:
# ProdTaken     0    1   All
# OwnCar
# All        3831  891  4722
# 1          2378  540  2918
# 0          1453  351  1804
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(df, "Designation", "ProdTaken")
# Out:
# ProdTaken          0    1   All
# Designation
# All             3831  891  4722
# Executive       1253  537  1790
# Manager         1471  198  1669
# Senior Manager   594  120   714
# VP               205   20   225
# AVP              308   16   324
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(df, "ProductPitched", "ProdTaken")
# Out:
# ProdTaken          0    1   All
# ProductPitched
# All             3831  891  4722
# Basic           1253  537  1790
# Deluxe          1471  198  1669
# Standard         594  120   714
# King             205   20   225
# Super Deluxe     308   16   324
# ------------------------------------------------------------------------------------------------------------------------

# %%
# 26 ProdTaken vs. DurationOfPitch (boxplot)
plt.figure(figsize=(15, 5))
sns.boxplot(y="DurationOfPitch", x="ProdTaken", data=df)
plt.show()

# %%
# drop outlier observations for duration of pitch
df.drop(index=df[df.DurationOfPitch > 37].index, inplace=True)

# %%
# 26 ProdTaken vs. DurationOfPitch (boxplot)
plt.figure(figsize=(15, 5))
sns.boxplot(y="DurationOfPitch", x="ProdTaken", data=df)
plt.show()

# %%
# ProdTaken vs. Monthly Income
plt.figure(figsize=(15, 5))
sns.boxplot(y="MonthlyIncome", x="ProdTaken", data=df)
plt.show()

# %%
# Dropping observation with monthly income less than 12000 or greater than 40000. There are just 4 such observations
df.drop(
    index=df[(df.MonthlyIncome > 40000) | (df.MonthlyIncome < 12000)].index,
    inplace=True,
)

# %%
# ProdTaken vs. Monthly Income
plt.figure(figsize=(15, 5))
sns.boxplot(y="MonthlyIncome", x="ProdTaken", data=df)
plt.show()

# OBSERVATION: Customers who bought the package have a lower monthly income than those who did not. Below, create a new plot that adds Designation on the x-axis and visualsize PrdoTaken as the hue.

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(y="MonthlyIncome", x="Designation", hue="ProdTaken", data=df)
plt.show()

# OBSERVATION: VP and AVP have higher incomes, but in every designation the folks with lower median tend to buy the packages. There are outliers who purchase travel packages.

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 26.a ProdTaken vs. Age (lineplot)
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>X variables</span> <span style='color:darkblue'>Younger people purchase the travel packages more than older people</span>

# %%
sns.lineplot(x="Age", y="ProdTaken", data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='ProdTaken'>

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 26.b Group data with respect to the 'Basic' package type (to build a customer profile)
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Mean Age; Mean Income</span> <span style='color:darkblue'>mean age=31; mean income=20,100</span>
#
# * <span style='color:#0e92ea'>Top Demographic</span> <span style='color:darkblue'>Single Salaried Male Executive </span>

# %%
df[(df["ProductPitched"] == "Basic") & (df["ProdTaken"] == 1)].describe(include="all").T
# Out:
#                           count unique           top   freq     mean     std  \
# ProdTaken                537.00    NaN           NaN    NaN     1.00    0.00
# Age                      502.00    NaN           NaN    NaN    31.26    9.13
# TypeofContact               537      2  Self Enquiry    349      NaN     NaN
# CityTier                 537.00   3.00          1.00 380.00      NaN     NaN
# DurationOfPitch          520.00    NaN           NaN    NaN    15.74    7.90
# Occupation                  537      4      Salaried    251      NaN     NaN
# Gender                      537      2          Male    333      NaN     NaN
# NumberOfPersonVisiting   537.00   3.00          3.00 269.00      NaN     NaN
# NumberOfFollowups        533.00   6.00          4.00 229.00      NaN     NaN
# ProductPitched              537      1         Basic    537      NaN     NaN
# PreferredPropertyStar    537.00   3.00          3.00 272.00      NaN     NaN
# ...

# %% [markdown]
# <font color=orange>
#
# ## 26.b Group data with respect to the 'Standard' package type (to build a customer profile)
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Mean Age; Mean Income</span> <span style='color:darkblue'>mean age=41; mean income=26,000</span>
#
# * <span style='color:#0e92ea'>Top Demographic</span> <span style='color:darkblue'>Married Male Senior Manager of a Small Business</span>

# %%
df[(df["ProductPitched"] == "Standard") & (df["ProdTaken"] == 1)].describe(
    include="all"
).T
# Out:
#                           count unique             top  freq     mean     std  \
# ProdTaken                120.00    NaN             NaN   NaN     1.00    0.00
# Age                      119.00    NaN             NaN   NaN    41.21    9.98
# TypeofContact               120      2    Self Enquiry    90      NaN     NaN
# CityTier                 120.00   3.00            3.00 62.00      NaN     NaN
# DurationOfPitch          119.00    NaN             NaN   NaN    19.03    9.03
# Occupation                  120      3  Small Business    58      NaN     NaN
# Gender                      120      2            Male    74      NaN     NaN
# NumberOfPersonVisiting   120.00   3.00            3.00 60.00      NaN     NaN
# NumberOfFollowups        120.00   6.00            4.00 54.00      NaN     NaN
# ProductPitched              120      1        Standard   120      NaN     NaN
# PreferredPropertyStar    119.00   3.00            3.00 68.00      NaN     NaN
# ...

# %% [markdown]
# <font color=orange>
#
# ## 26.b Group data with respect to the 'Deluxe' package type (to build a customer profile)
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Mean Age; Mean Income</span> <span style='color:darkblue'>mean age=37.7; mean income=23,100</span>
#
# * <span style='color:#0e92ea'>Top Demographic</span> <span style='color:darkblue'>Married Male Manager of a Small Business </span>

# %%
df[(df["ProductPitched"] == "Deluxe") & (df["ProdTaken"] == 1)].describe(
    include="all"
).T
# Out:
#                           count unique             top   freq     mean  \
# ProdTaken                198.00    NaN             NaN    NaN     1.00
# Age                      192.00    NaN             NaN    NaN    37.69
# TypeofContact               198      2    Self Enquiry    134      NaN
# CityTier                 198.00   2.00            3.00 140.00      NaN
# DurationOfPitch          175.00    NaN             NaN    NaN    19.06
# Occupation                  198      3  Small Business    102      NaN
# Gender                      198      2            Male    132      NaN
# NumberOfPersonVisiting   198.00   3.00            3.00  99.00      NaN
# NumberOfFollowups        194.00   6.00            4.00  75.00      NaN
# ProductPitched              198      1          Deluxe    198      NaN
# PreferredPropertyStar    197.00   3.00            3.00 112.00      NaN
# MaritalStatus               198      4         Married     68      NaN
# ...

# %% [markdown]
# <font color=orange>
#
# ## 26.b Group data with respect to the 'Super Deluxe' package type (to build a customer profile)
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Mean Age; Mean Income</span> <span style='color:darkblue'>mean age=44; mean income=29,800</span>
#
# * <span style='color:#0e92ea'>Top Demographic</span> <span style='color:darkblue'>Single Salaried Male Associate Vice President </span>

# %%
df[(df["ProductPitched"] == "Super Deluxe") & (df["ProdTaken"] == 1)].describe(
    include="all"
).T
# Out:
#                          count unique              top  freq     mean     std  \
# ProdTaken                16.00    NaN              NaN   NaN     1.00    0.00
# Age                      16.00    NaN              NaN   NaN    44.12    5.19
# TypeofContact               16      2  Company Invited    12      NaN     NaN
# CityTier                 16.00   2.00             3.00 14.00      NaN     NaN
# DurationOfPitch          16.00    NaN              NaN   NaN    19.75    7.28
# Occupation                  16      2         Salaried    12      NaN     NaN
# Gender                      16      2             Male    12      NaN     NaN
# NumberOfPersonVisiting   16.00   3.00             3.00  8.00      NaN     NaN
# NumberOfFollowups        16.00   6.00             1.00  4.00      NaN     NaN
# ProductPitched              16      1     Super Deluxe    16      NaN     NaN
# PreferredPropertyStar    16.00   3.00             3.00 10.00      NaN     NaN
# ...

# %% [markdown]
# <font color=orange>
#
# ## 26.b Group data with respect to the 'King' package type (to build a customer profile)
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Mean Age; Mean Income</span> <span style='color:darkblue'>mean age=48.9; mean income=34,600</span>
#
# * <span style='color:#0e92ea'>Top Demographic</span> <span style='color:darkblue'>Single Female Vice President of a Small Business </span>

# %%
df[(df["ProductPitched"] == "King") & (df["ProdTaken"] == 1)].describe(include="all").T
# Out:
#                          count unique             top  freq     mean     std  \
# ProdTaken                20.00    NaN             NaN   NaN     1.00    0.00
# Age                      20.00    NaN             NaN   NaN    48.90    9.62
# TypeofContact               20      1    Self Enquiry    20      NaN     NaN
# CityTier                 20.00   2.00            1.00 12.00      NaN     NaN
# DurationOfPitch          20.00    NaN             NaN   NaN    10.50    4.14
# Occupation                  20      3  Small Business    12      NaN     NaN
# Gender                      20      2          Female    12      NaN     NaN
# NumberOfPersonVisiting   20.00   3.00            3.00 10.00      NaN     NaN
# NumberOfFollowups        20.00   4.00            3.00  6.00      NaN     NaN
# ProductPitched              20      1            King    20      NaN     NaN
# PreferredPropertyStar    16.00   3.00            4.00  8.00      NaN     NaN
# ...

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 27. Separate the data into Dependent and Independent Variables
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>X variables</span> <span style='color:darkblue'>Isolate all of the independent variables (other than ProdTaken) which possess the data that will be used to make predictions </span>
#
# * <span style='color:#0e92ea'>y variable</span> <span style='color:darkblue'>Isolate ProdTaken as the y variable -- the target variable -- that has the data which will be predicted </span>

# %%
X = df.drop(["ProdTaken"], axis=1)
y = df["ProdTaken"]

# %%
y.dtypes
# Out:
# dtype('int64')

# %%
X.dtypes
# Out:
# Age                          float64
# TypeofContact               category
# CityTier                    category
# DurationOfPitch              float64
# Occupation                  category
# Gender                      category
# NumberOfPersonVisiting      category
# NumberOfFollowups           category
# ProductPitched              category
# PreferredPropertyStar       category
# MaritalStatus               category
# NumberOfTrips                float64
# Passport                    category
# PitchSatisfactionScore      category
# OwnCar                      category
# NumberOfChildrenVisiting    category
# Designation                 category
# MonthlyIncome                float64
# dtype: object

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4716 entries, 0 to 4887
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       4501 non-null   float64
#  1   TypeofContact             4716 non-null   category
#  2   CityTier                  4716 non-null   category
#  3   DurationOfPitch           4495 non-null   float64
#  4   Occupation                4716 non-null   category
#  5   Gender                    4716 non-null   category
#  6   NumberOfPersonVisiting    4716 non-null   category
#  7   NumberOfFollowups         4672 non-null   category
#  8   ProductPitched            4716 non-null   category
#  9   PreferredPropertyStar     4691 non-null   category
#  10  MaritalStatus             4716 non-null   category
#  11  NumberOfTrips             4578 non-null   float64
#  12  Passport                  4716 non-null   category
# ...

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 27. FEATURES THAT WOULD NOT HAVE BEEN AVAILABLE AT THE TIME OF ProdTaken PREDICTION (ie: the following were 'subsequent data attributes')
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>DurationOfPitch</span> <span style='color:darkblue'>drop</span>
#
# * <span style='color:#0e92ea'>NumberOfFollowups</span> <span style='color:darkblue'>drop</span>
#
# * <span style='color:#0e92ea'>ProductPitched</span> <span style='color:darkblue'>drop</span>
#
# * <span style='color:#0e92ea'>PitchSatisfactionScore</span> <span style='color:darkblue'>drop</span>

# %%
# Dropping columns
X.drop(
    columns=[
        "DurationOfPitch",
        "NumberOfFollowups",
        "ProductPitched",
        "PitchSatisfactionScore",
    ],
    inplace=True,
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1707-ecabc77269e6> in <module>
#       1 # Dropping columns
# ----> 2 X.drop(
#       3     columns=[
#       4         "DurationOfPitch",
#       5         "NumberOfFollowups",
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ...

# %%
X.columns
# Out:
# Index(['Age', 'TypeofContact', 'CityTier', 'Occupation', 'Gender',
#        'NumberOfPersonVisiting', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'OwnCar', 'NumberOfChildrenVisiting',
#        'Designation', 'MonthlyIncome'],
#       dtype='object')

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 30. SPLIT: Training Set Data and Testing Set Data
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>SKLearn train_test_split() Function:</span> <span style='color:darkblue'>This function yields two (2) subsets: X_train, X_test, & y_train, y_test</span>
#
# * <span style='color:#0e92ea'>Percentage Splits:</span> <span style='color:darkblue'>70% of data will be used for training and 30% will be used for testing.

# %%
# Splitting data into training and test set:
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y
)
print(X_train.shape, X_test.shape)
# Out:
# (3301, 14) (1415, 14)

# %%
y.value_counts(1)
# Out:
# 0   0.81
# 1   0.19
# Name: ProdTaken, dtype: float64

# %%
y_test.value_counts(1)
# Out:
# 0   0.81
# 1   0.19
# Name: ProdTaken, dtype: float64

# %%
print("Shape of Training set : ", X_train.shape)
print("\n")
print("Shape of test set : ", X_test.shape)
print("\n")
print("Percentage of classes in training set:")
print("\n")
print(y_train.value_counts(normalize=True))
print("\n")
print("Percentage of classes in test set:")
print("\n")
print(y_test.value_counts(normalize=True))
# Out:
# Shape of Training set :  (3301, 14)
#
#
# Shape of test set :  (1415, 14)
#
#
# Percentage of classes in training set:
#
#
# 0   0.81
# 1   0.19
# Name: ProdTaken, dtype: float64
#
#
# Percentage of classes in test set:
#
#
# 0   0.81
# 1   0.19
# Name: ProdTaken, dtype: float64

# %%
# Check the percentage of the split data

print("{0:0.2f}% data is in training set".format((len(X_train) / len(df.index)) * 100))
print("{0:0.2f}% data is in test set".format((len(X_test) / len(df.index)) * 100))
# Out:
# 70.00% data is in training set
# 30.00% data is in test set

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 30a. IMPUTE MISSING VALUES

# %%
si1 = SimpleImputer(strategy="median")

median_imputed_col = ["Age", "MonthlyIncome", "NumberOfTrips"]

# Fit and transform the train data
X_train[median_imputed_col] = si1.fit_transform(X_train[median_imputed_col])

# Transform the test data (i.e. replace missing values with the median that will be calculated using training data)
X_test[median_imputed_col] = si1.transform(X_test[median_imputed_col])

# %%
si2 = SimpleImputer(strategy="most_frequent")

mode_imputed_col = [
    "TypeofContact",
    "PreferredPropertyStar",
    "NumberOfChildrenVisiting",
]

# Fit and transform the train data
X_train[mode_imputed_col] = si2.fit_transform(X_train[mode_imputed_col])

# Transform the test data (i.e. replace missing values with the mode that will be calculated using training data)
X_test[mode_imputed_col] = si2.transform(X_test[mode_imputed_col])

# %%
# Ensure no missing values in training set or testing set

print(X_train.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# Age                         0
# TypeofContact               0
# CityTier                    0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64
# ------------------------------
# Age                         0
# TypeofContact               0
# CityTier                    0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 28. Dummy Coding: One Hot Encoding
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>One Hot Encoding</span> <span style='color:darkblue'>Type of Contact, City Tier, Occupation, Product Pitched, Preferred Property Star, Marital Status, Passport, Own Car, and Designation will be one hot encoded</span>
#
# * <span style='color:#0e92ea'>Shape Attribute</span> <span style='color:darkblue'>one hot encoding expanded the shape of the dataset to 30 columns</span>

# %%
# converting data types of columns to float
for column in [
    "NumberOfPersonVisiting",
    "Passport",
    "OwnCar",
    "NumberOfChildrenVisiting",
    "PreferredPropertyStar",
]:
    X_train[column] = X_train[column].astype("float")
    X_test[column] = X_test[column].astype("float")

# %%
# Please read observation above

# List of columns to create a dummy variables
col_dummy = [
    "TypeofContact",
    "Occupation",
    "Gender",
    "MaritalStatus",
    "Designation",
    "CityTier",
]

# Encoding categorical varaibles
X_train = pd.get_dummies(X_train, columns=col_dummy, drop_first=True)
X_test = pd.get_dummies(X_test, columns=col_dummy, drop_first=True)

# %%
X_train.shape
# Out:
# (3301, 22)

# %%
X_test.shape
# Out:
# (1415, 22)

# %% [markdown]
# ***

# %% [markdown]
# # Building the Models

# %% [markdown]
# ### Model evaluation criterion:
#
# #### The model can make wrong predictions as:
# 1. Predicting a customer will buy the product but the customer doesn't buy... - this results in a loss of resources
# 2. Predicting a customer will not buy the product but the customer buys - this results in a loss of opportunity
#
# #### Which case is more important?
# * Predicting that customer will not buy the product but the customer buys (i.e. it is important not to lose a potential source of income for the company, especially if that customer will not be targeted by the marketing team when, in fact, that customer should be targeted.
#
# #### How to reduce this loss i.e need to reduce False Negatives?
# * The model's Recall score should be maximized; the greater the Recall... the less chance of predicting false negatives.

# %% [markdown]
# ***

# %% [markdown]
# # Create two functions to calculate different metrics and confusion matrices.

# %%
# defining a function to compute different metrics to check performance of a classification model built using sklearn
def model_performance_classification_sklearn(model, predictors, target):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred)  # to compute Recall
    precision = precision_score(target, pred)  # to compute Precision
    f1 = f1_score(target, pred)  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "Accuracy": acc,
            "Recall": recall,
            "Precision": precision,
            "F1": f1,
        },
        index=[0],
    )

    return df_perf

# %%
def confusion_matrix_sklearn(model, predictors, target):
    """
    To plot the confusion_matrix with percentages

    model: classifier
    predictors: independent variables
    target: dependent variable
    """
    y_pred = model.predict(predictors)
    cm = confusion_matrix(target, y_pred)
    labels = np.asarray(
        [
            ["{0:0.0f}".format(item) + "\n{0:.2%}".format(item / cm.flatten().sum())]
            for item in cm.flatten()
        ]
    ).reshape(2, 2)

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 32. DECISION TREE (without hyperparameter tuning)
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>The Decision Tree model is overfitting the training data. Reduce overfitting and improve performance by tuning some hyperparameters</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>The Decision Tree model has a very low R-squared score and Adjusted R-squared score.</span>

# %%
# Fitting the model
d_tree = DecisionTreeClassifier(random_state=1)
d_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
# Calculating different metrics
d_tree_model_train_perf = model_performance_classification_sklearn(
    d_tree, X_train, y_train
)
print("Training performance:\n", d_tree_model_train_perf)
d_tree_model_test_perf = model_performance_classification_sklearn(
    d_tree, X_test, y_test
)
print("Testing performance:\n", d_tree_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      1.00    1.00       1.00 1.00
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.87    0.68       0.64 0.66

# %%
# Creating confusion matrix
confusion_matrix_sklearn(d_tree, X_test, y_test)

# %% [markdown]
# ### Cost Complexity Pruning
#
# **pruning the tree in an attempt to improve performance.**

# %%
path = d_tree.cost_complexity_pruning_path(X_train, y_train)

ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
clfs_list = []

for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=1, ccp_alpha=ccp_alpha)
    clf.fit(X_train, y_train)
    clfs_list.append(clf)

print(
    "Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
        clfs_list[-1].tree_.node_count, ccp_alphas[-1]
    )
)
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.022164444441974185

# %%
# Fit the model for each value of alpha and save the TRAIN RECALL to a list

recall_train = []
for clf in clfs_list:
    pred_train = clf.predict(X_train)
    values_train = metrics.recall_score(y_train, pred_train)
    recall_train.append(values_train)

# %%
# Fit model for each value of alpha and saving the TEST RECALL to a list

recall_test = []
for clf in clfs_list:
    pred_test = clf.predict(X_test)
    values_test = metrics.recall_score(y_test, pred_test)
    recall_test.append(values_test)

# %%
# Plot the graph for Recall vs. Alpha

fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlabel("alpha")
ax.set_ylabel("Recall")
ax.set_title("Recall vs Alpha for training and testing sets")
ax.plot(ccp_alphas, recall_train, marker="o", label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, recall_test, marker="o", label="test", drawstyle="steps-post")
ax.legend()
plt.show()

# %%
# Create the model where that returns the highest test recall

index_best_pruned_model = np.argmax(recall_test)

pruned_dtree_model = clfs_list[index_best_pruned_model]

# %%
# Calculating the different train/test metrics

pruned_dtree_model_train_perf = model_performance_classification_sklearn(
    pruned_dtree_model, X_train, y_train
)
print("Training performance:\n", pruned_dtree_model_train_perf)
pruned_dtree_model_test_perf = model_performance_classification_sklearn(
    pruned_dtree_model, X_test, y_test
)
print("Testing performance:\n", pruned_dtree_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      1.00    1.00       1.00 1.00
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.87    0.68       0.64 0.66

# %%
# Create a confusion matrix

confusion_matrix_sklearn(pruned_dtree_model, X_test, y_test)

# %% [markdown]
# <font color=orange>
#
# ## 33. DECISION TREE with HYPERPARAMETER TUNING
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>Overfitting has not been reduced.</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>An even lower R squared value which means that the independent variables are not explaining much in the variation of the dependent variables. </span>

# %%
# Choose the type of classifier.
dtree_estimator = DecisionTreeClassifier(
    class_weight={0: 0.18, 1: 0.72}, random_state=1
)

# Grid of parameters to choose from
parameters = {
    "max_depth": np.arange(2, 30),
    "min_samples_leaf": [1, 2, 5, 7, 10],
    "max_leaf_nodes": [2, 3, 5, 10, 15],
    "min_impurity_decrease": [0.0001, 0.001, 0.01, 0.1],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Run the grid search
grid_obj = GridSearchCV(dtree_estimator, parameters, scoring=scorer, n_jobs=-1)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
dtree_estimator = grid_obj.best_estimator_

# Fit the best algorithm to the data.
dtree_estimator.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={0: 0.18, 1: 0.72}, max_depth=8,
#                        max_leaf_nodes=15, min_impurity_decrease=0.0001,
#                        random_state=1)

# %%
# Calculating different metrics
dtree_estimator_model_train_perf = model_performance_classification_sklearn(
    dtree_estimator, X_train, y_train
)
print("Training performance:\n", dtree_estimator_model_train_perf)
dtree_estimator_model_test_perf = model_performance_classification_sklearn(
    dtree_estimator, X_test, y_test
)
print("Testing performance:\n", dtree_estimator_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      0.78    0.68       0.45 0.54
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.78    0.60       0.44 0.50

# %%
# Creating confusion matrix
confusion_matrix_sklearn(dtree_estimator, X_test, y_test)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 35. RANDOM FOREST (without hyperparameter tuning)
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>Random Forest is still slightly overfitting at .939 R-squared.</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>R-squared score of .585 is not too good; try tuning algorithmic hyperparameters to improve the Random Forest fit</span>

# %%
# Fitting the model
rf_estimator = RandomForestClassifier(random_state=1)
rf_estimator.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Calculating different metrics
rf_estimator_model_train_perf = model_performance_classification_sklearn(
    rf_estimator, X_train, y_train
)
print("Training performance:\n", rf_estimator_model_train_perf)
rf_estimator_model_test_perf = model_performance_classification_sklearn(
    rf_estimator, X_test, y_test
)
print("Testing performance:\n", rf_estimator_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      1.00    1.00       1.00 1.00
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.89    0.52       0.84 0.64

# %%
# Creating confusion matrix
confusion_matrix_sklearn(rf_estimator, X_test, y_test)

# %% [markdown]
# <font color=orange>
#
# ## 36. RANDOM FOREST with HYPERPARAMETER TUNING
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>No change, really.  The R-sqaured value is almost the same as the untuned Random Forest</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>No change, really.  The R-sqaured value is almost the same as the untuned Random Forest </span>

# %%
# Choose the type of classifier.
rf_tuned = RandomForestClassifier(
    class_weight={0: 0.18, 1: 0.82}, random_state=1, oob_score=True, bootstrap=True
)

parameters = {
    "max_depth": list(np.arange(5, 30, 5)) + [None],
    "max_features": ["sqrt", "log2", None],
    "min_samples_leaf": np.arange(1, 15, 5),
    "min_samples_split": np.arange(2, 20, 5),
    "n_estimators": np.arange(10, 110, 10),
}


# Run the grid search
grid_obj = GridSearchCV(rf_tuned, parameters, scoring="recall", cv=5, n_jobs=-1)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
rf_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
rf_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={0: 0.18, 1: 0.82}, max_depth=5,
#                        max_features='sqrt', min_samples_split=7,
#                        n_estimators=70, oob_score=True, random_state=1)

# %%
# Calculating different metrics
rf_tuned_model_train_perf = model_performance_classification_sklearn(
    rf_tuned, X_train, y_train
)
print("Training performance:\n", rf_tuned_model_train_perf)
rf_tuned_model_test_perf = model_performance_classification_sklearn(
    rf_tuned, X_test, y_test
)
print("Testing performance:\n", rf_tuned_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      0.79    0.75       0.47 0.58
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.79    0.66       0.46 0.54

# %%
# Creating confusion matrix
confusion_matrix_sklearn(rf_tuned, X_test, y_test)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 38. BAGGING CLASSIFIER (without hyperparameter tuning)
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>Adaboost is performing poorly. R-squared and RMSE are very low compared to decision tree and random forest models.</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>Adaboost is performing poorly. R-squared and RMSE are very low compared to decision tree and random forest models.</span>

# %%
# Fitting the model
bagging_classifier = BaggingClassifier(random_state=1)
bagging_classifier.fit(X_train, y_train)

# Calculating different metrics
bagging_classifier_model_train_perf = model_performance_classification_sklearn(
    bagging_classifier, X_train, y_train
)
print("Training performance:\n", bagging_classifier_model_train_perf)
bagging_classifier_model_test_perf = model_performance_classification_sklearn(
    bagging_classifier, X_test, y_test
)
print("Testing performance:\n", bagging_classifier_model_test_perf)

# Creating confusion matrix
confusion_matrix_sklearn(bagging_classifier, X_test, y_test)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      0.99    0.96       1.00 0.98
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.88    0.56       0.75 0.64

# %% [markdown]
# <font color=orange>
#
# ## 38. BAGGING CLASSIFIER (with hyperparameter tuning)
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>Adaboost is performing poorly. R-squared and RMSE are very low compared to decision tree and random forest models.</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>Adaboost is performing poorly. R-squared and RMSE are very low compared to decision tree and random forest models.</span>

# %%
# Choose the type of classifier.
bagging_estimator_tuned = BaggingClassifier(random_state=1)

# Grid of parameters to choose from
parameters = {
    "max_samples": [0.7, 0.8, 0.9, 1],
    "max_features": [0.7, 0.8, 0.9, 1],
    "n_estimators": [10, 20, 30, 40, 50],
}

# Type of scoring used to compare parameter combinations
acc_scorer = metrics.make_scorer(metrics.recall_score)

# Run the grid search
grid_obj = GridSearchCV(bagging_estimator_tuned, parameters, scoring=acc_scorer, cv=5)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
bagging_estimator_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
bagging_estimator_tuned.fit(X_train, y_train)
# Out:
# BaggingClassifier(max_features=0.9, max_samples=0.9, n_estimators=50,
#                   random_state=1)

# %%
# Calculating different metrics
bagging_estimator_tuned_model_train_perf = model_performance_classification_sklearn(
    bagging_estimator_tuned, X_train, y_train
)
print("Training performance:\n", bagging_estimator_tuned_model_train_perf)
bagging_estimator_tuned_model_test_perf = model_performance_classification_sklearn(
    bagging_estimator_tuned, X_test, y_test
)
print("Testing performance:\n", bagging_estimator_tuned_model_test_perf)

# Creating confusion matrix
confusion_matrix_sklearn(bagging_estimator_tuned, X_test, y_test)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      1.00    0.99       1.00 1.00
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.90    0.58       0.84 0.68

# %% [markdown]
# ***

# %% [markdown]
# # BOOSTING MODELS

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 38. ADAPTIVE BOOSTING CLASSIFIER (without hyperparameter tuning)
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>Adaboost is performing poorly. R-squared and RMSE are very low compared to decision tree and random forest models.</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>Adaboost is performing poorly. R-squared and RMSE are very low compared to decision tree and random forest models.</span>

# %%
# Fitting the model
ab_classifier = AdaBoostClassifier(random_state=1)
ab_classifier.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(random_state=1)

# %%
# Calculating different metrics
ab_classifier_model_train_perf = model_performance_classification_sklearn(
    ab_classifier, X_train, y_train
)
print("Training performance:\n", ab_classifier_model_train_perf)
ab_classifier_model_test_perf = model_performance_classification_sklearn(
    ab_classifier, X_test, y_test
)
print("Testing performance:\n", ab_classifier_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      0.84    0.31       0.70 0.43
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.84    0.30       0.68 0.41

# %%
# Creating confusion matrix
confusion_matrix_sklearn(ab_classifier, X_test, y_test)

# %% [markdown]
# <font color=orange>
#
# ## 39. ADAPTIVE BOOSTING with HYPERPARAMETER TUNING
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>There is slight improvement, however Adaboost is still performing poorly</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>There is slight improvement, however Adaboost is still performing poorly </span>

# %%
# Choose the type of classifier.
abc_tuned = AdaBoostClassifier(random_state=1)

# Grid of parameters to choose from
parameters = {
    # Let's try different max_depth for base_estimator
    "base_estimator": [
        DecisionTreeClassifier(max_depth=1),
        DecisionTreeClassifier(max_depth=2),
        DecisionTreeClassifier(max_depth=3),
    ],
    "n_estimators": np.arange(10, 110, 10),
    "learning_rate": np.arange(0.1, 2, 0.1),
}

# Type of scoring used to compare parameter  combinations
acc_scorer = metrics.make_scorer(metrics.recall_score)

# Run the grid search
grid_obj = GridSearchCV(abc_tuned, parameters, scoring=acc_scorer, cv=5)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
abc_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
abc_tuned.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=3),
#                    learning_rate=1.8000000000000003, n_estimators=100,
#                    random_state=1)

# %%
# Calculating different metrics
abc_tuned_model_train_perf = model_performance_classification_sklearn(
    abc_tuned, X_train, y_train
)
print("Training performance:\n", abc_tuned_model_train_perf)
abc_tuned_model_test_perf = model_performance_classification_sklearn(
    abc_tuned, X_test, y_test
)
print("Testing performance:\n", abc_tuned_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      0.95    0.83       0.88 0.86
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.85    0.51       0.64 0.57

# %%
# Creating confusion matrix
confusion_matrix_sklearn(abc_tuned, X_test, y_test)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 41. GRADIENT BOOSTING CLASSIFIER (without hyperparameter tuning)
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>Gradient Boosting has the best R-squared value so far, but it is still very low, which means poor performance by the model in fitting the data</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>Gradient Boosting has the best R-squared value so far, but it is still very low, which means poor performance by the model in fitting the data</span>

# %%
# Fitting the model
gb_classifier = GradientBoostingClassifier(random_state=1)
gb_classifier.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
# Calculating different metrics
gb_classifier_model_train_perf = model_performance_classification_sklearn(
    gb_classifier, X_train, y_train
)
print("Training performance:\n", gb_classifier_model_train_perf)
gb_classifier_model_test_perf = model_performance_classification_sklearn(
    gb_classifier, X_test, y_test
)
print("Testing performance:\n", gb_classifier_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      0.88    0.43       0.87 0.58
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.87    0.43       0.83 0.56

# %%
# Creating confusion matrix
confusion_matrix_sklearn(gb_classifier, X_test, y_test)

# %% [markdown]
# <font color=orange>
#
# ## 42. GRADIENT BOOSTING with HYPERPARAMETER TUNING
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>The Gradient Boosting model with hyperparameter tuning is overfitting the training data.</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'> However, the Gradient Boosting model with hyperparameter tuning is the best performing model so far on the training data. R-squared = .637; getting better!</span>

# %%
# Choose the type of classifier.
gbc_tuned = GradientBoostingClassifier(
    init=AdaBoostClassifier(random_state=1), random_state=1
)

# Grid of parameters to choose from
parameters = {
    "n_estimators": [100, 150, 200, 250],
    "subsample": [0.8, 0.9, 1],
    "max_features": [0.7, 0.8, 0.9, 1],
}

# Type of scoring used to compare parameter combinations
acc_scorer = metrics.make_scorer(metrics.recall_score)

# Run the grid search
grid_obj = GridSearchCV(gbc_tuned, parameters, scoring=acc_scorer, cv=5)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
gbc_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
gbc_tuned.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(init=AdaBoostClassifier(random_state=1),
#                            max_features=0.9, n_estimators=250, random_state=1,
#                            subsample=0.8)

# %%
# Calculating different metrics
gbc_tuned_model_train_perf = model_performance_classification_sklearn(
    gbc_tuned, X_train, y_train
)
print("Training performance:\n", gbc_tuned_model_train_perf)
gbc_tuned_model_test_perf = model_performance_classification_sklearn(
    gbc_tuned, X_test, y_test
)
print("Testing performance:\n", gbc_tuned_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      0.92    0.60       0.93 0.73
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.88    0.51       0.78 0.62

# %%
# Creating confusion matrix
confusion_matrix_sklearn(gbc_tuned, X_test, y_test)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 44. XGBOOST CLASSIFIER (without hyperparameter tuning)
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>XGBoost with default parameters gives a slightly overfit R-squared score</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>The XGBoost with default parameters performs at an R-squared score of 0.572. It's slightly better than flipping coin. </span>

# %%
# Fitting the model
xgb_classifier = XGBClassifier(random_state=1, eval_metric="error")
xgb_classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='error',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, random_state=1, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=1, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
# Calculating different metrics
xgb_classifier_model_train_perf = model_performance_classification_sklearn(
    xgb_classifier, X_train, y_train
)
print("Training performance:\n", xgb_classifier_model_train_perf)
xgb_classifier_model_test_perf = model_performance_classification_sklearn(
    xgb_classifier, X_test, y_test
)
print("Testing performance:\n", xgb_classifier_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      1.00    0.98       1.00 0.99
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.90    0.63       0.82 0.71

# %%
# Creating confusion matrix
confusion_matrix_sklearn(xgb_classifier, X_test, y_test)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 45. XGBOOST with HYPERPARAMETER TUNING
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>XGBoost with hyperparameter tuning yielded an R-squared score of .987 on training data</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>XGBoost with hyperparameters tuning yielded the second best performance so far with an R-squared score of 0.608.</span>

# %%
# Choose the type of classifier.
xgb_tuned = XGBClassifier(random_state=1, eval_metric="logloss")

# Grid of parameters to choose from
parameters = {
    "n_estimators": np.arange(10, 100, 20),
    "scale_pos_weight": [0, 1, 2, 5],
    "subsample": [0.5, 0.7, 0.9, 1],
    "learning_rate": [0.01, 0.1, 0.2, 0.05],
    "gamma": [0, 1, 3],
    "colsample_bytree": [0.5, 0.7, 0.9, 1],
    "colsample_bylevel": [0.5, 0.7, 0.9, 1],
}

# Type of scoring used to compare parameter combinations
acc_scorer = metrics.make_scorer(metrics.recall_score)

# Run the grid search
grid_obj = GridSearchCV(xgb_tuned, parameters, scoring=acc_scorer, cv=5)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
xgb_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
xgb_tuned.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=0.5,
#               colsample_bynode=1, colsample_bytree=0.5, eval_metric='logloss',
#               gamma=3, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#               max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=30, n_jobs=8,
#               num_parallel_tree=1, random_state=1, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=5, subsample=0.9, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
# Calculating different metrics
xgb_tuned_model_train_perf = model_performance_classification_sklearn(
    xgb_tuned, X_train, y_train
)
print("Training performance:\n", xgb_tuned_model_train_perf)
xgb_tuned_model_test_perf = model_performance_classification_sklearn(
    xgb_tuned, X_test, y_test
)
print("Testing performance:\n", xgb_tuned_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      0.79    0.86       0.47 0.60
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.76    0.73       0.43 0.54

# %%
# Creating confusion matrix
confusion_matrix_sklearn(xgb_tuned, X_test, y_test)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 47. STACKING MODEL
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Training:</span> <span style='color:darkblue'>built a stacking model with the tuned models - decision tree, random forest, and gradient boosting, then use XGBoost to get the final prediction.</span>
#
# * <span style='color:#0e92ea'>Testing:</span> <span style='color:darkblue'>R-squared Score of .587</span>

# %%
estimators = [
    ("Random Forest", rf_tuned),
    ("Gradient Boosting", gbc_tuned),
    ("Decision Tree", dtree_estimator),
]

final_estimator = xgb_tuned

# %%
stacking_classifier = StackingClassifier(
    estimators=estimators, final_estimator=final_estimator
)

stacking_classifier.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('Random Forest',
#                                 RandomForestClassifier(class_weight={0: 0.18,
#                                                                      1: 0.82},
#                                                        max_depth=5,
#                                                        max_features='sqrt',
#                                                        min_samples_split=7,
#                                                        n_estimators=70,
#                                                        oob_score=True,
#                                                        random_state=1)),
#                                ('Gradient Boosting',
#                                 GradientBoostingClassifier(init=AdaBoostClassifier(random_state=1),
#                                                            max_features=0.9,
#                                                            n_estimators=250,
# ...

# %%
# Calculating different metrics
stacking_classifier_model_train_perf = model_performance_classification_sklearn(
    stacking_classifier, X_train, y_train
)
print("Training performance:\n", stacking_classifier_model_train_perf)
stacking_classifier_model_test_perf = model_performance_classification_sklearn(
    stacking_classifier, X_test, y_test
)
print("Testing performance:\n", stacking_classifier_model_test_perf)
# Out:
# Training performance:
#     Accuracy  Recall  Precision   F1
# 0      0.83    0.83       0.53 0.65
# Testing performance:
#     Accuracy  Recall  Precision   F1
# 0      0.79    0.71       0.46 0.56

# %%
# Creating confusion matrix
confusion_matrix_sklearn(stacking_classifier, X_test, y_test)

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 48. COMPARE ALL OF THE MODELS (Training Data & Testing Data)

# %% [markdown]
# <font color=orange>
#
# ## 49. PERFORMANCE COMPARISONS OF THE TRAINING DATA
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Tuned Gradient Boosting:</span> <span style='color:darkblue'>The tuned gradient boosting model is the best model here. It has the highest r2 score of approx 95.5% and the lowest RMSE of approx 39 on the test data. </span>
#
# * <span style='color:#0e92ea'>Top 3 Models:</span> <span style='color:darkblue'>Gradient boosting, XGBoost, and stacking regressor are the top 3 models. They are all giving a similar performance. </span>

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [
        d_tree_model_train_perf.T,
        pruned_dtree_model_train_perf.T,
        dtree_estimator_model_train_perf.T,
        rf_estimator_model_train_perf.T,
        rf_tuned_model_train_perf.T,
        bagging_classifier_model_train_perf.T,
        bagging_estimator_tuned_model_train_perf.T,
        ab_classifier_model_train_perf.T,
        abc_tuned_model_train_perf.T,
        gb_classifier_model_train_perf.T,
        gbc_tuned_model_train_perf.T,
        xgb_classifier_model_train_perf.T,
        xgb_tuned_model_train_perf.T,
        stacking_classifier_model_train_perf.T,
    ],
    axis=1,
)
models_train_comp_df.columns = [
    "Decision Tree",
    "Prunned Decision Tree",
    "Decision Tree Estimator",
    "Random Forest Estimator",
    "Random Forest Tuned",
    "Bagging Classifier",
    "Bagging Estimator Tuned",
    "Adaboost Classifier",
    "Adaboost Classifier Tuned",
    "Gradient Boost Classifier",
    "Gradient Boost Classifier Tuned",
    "XGBoost Classifier",
    "XGBoost Classifier Tuned",
    "Stacking Classifier",
]
print("Training performance comparison:")
models_train_comp_df
# Out:
# Training performance comparison:
#            Decision Tree  Prunned Decision Tree  Decision Tree Estimator  \
# Accuracy            1.00                   1.00                     0.78
# Recall              1.00                   1.00                     0.68
# Precision           1.00                   1.00                     0.45
# F1                  1.00                   1.00                     0.54
#
#            Random Forest Estimator  Random Forest Tuned  Bagging Classifier  \
# Accuracy                      1.00                 0.79                0.99
# Recall                        1.00                 0.75                0.96
# Precision                     1.00                 0.47                1.00
# F1                            1.00                 0.58                0.98
#
#            Bagging Estimator Tuned  Adaboost Classifier  \
# Accuracy                      1.00                 0.84
# Recall                        0.99                 0.31
# ...

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 50. Performance Comparisons of the Testing Data
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Tuned Gradient Boosting:</span> <span style='color:darkblue'>The tuned gradient boosting model is the best model here. It has the highest r2 score of approx 64% on testing data. </span>
#
# * <span style='color:#0e92ea'>Top 3 Models:</span> <span style='color:darkblue'>Gradient boosting tuned, XGBoost tuned, and stacking regressor are the top 3 models. They are all giving a similar performance, though not ideal. </span>

# %%
# Testing performance comparison

models_test_comp_df = pd.concat(
    [
        d_tree_model_test_perf.T,
        pruned_dtree_model_test_perf.T,
        dtree_estimator_model_test_perf.T,
        rf_estimator_model_test_perf.T,
        rf_tuned_model_test_perf.T,
        bagging_classifier_model_test_perf.T,
        bagging_estimator_tuned_model_test_perf.T,
        ab_classifier_model_test_perf.T,
        abc_tuned_model_test_perf.T,
        gb_classifier_model_test_perf.T,
        gbc_tuned_model_test_perf.T,
        xgb_classifier_model_test_perf.T,
        xgb_tuned_model_test_perf.T,
        stacking_classifier_model_test_perf.T,
    ],
    axis=1,
)
models_test_comp_df.columns = [
    "Decision Tree",
    "Prunned Decision Tree",
    "Decision Tree Estimator",
    "Random Forest Estimator",
    "Random Forest Tuned",
    "Bagging Classifier",
    "Bagging Estimator Tuned",
    "Adaboost Classifier",
    "Adaboost Classifier Tuned",
    "Gradient Boost Classifier",
    "Gradient Boost Classifier Tuned",
    "XGBoost Classifier",
    "XGBoost Classifier Tuned",
    "Stacking Classifier",
]
print("Testing performance comparison:")
models_test_comp_df
# Out:
# Testing performance comparison:
#            Decision Tree  Prunned Decision Tree  Decision Tree Estimator  \
# Accuracy            0.87                   0.87                     0.78
# Recall              0.68                   0.68                     0.60
# Precision           0.64                   0.64                     0.44
# F1                  0.66                   0.66                     0.50
#
#            Random Forest Estimator  Random Forest Tuned  Bagging Classifier  \
# Accuracy                      0.89                 0.79                0.88
# Recall                        0.52                 0.66                0.56
# Precision                     0.84                 0.46                0.75
# F1                            0.64                 0.54                0.64
#
#            Bagging Estimator Tuned  Adaboost Classifier  \
# Accuracy                      0.90                 0.84
# Recall                        0.58                 0.30
# ...

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 51. FEATURE IMPORTANCES

# %%
feature_names = X_train.columns
importances = xgb_tuned.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(12, 12))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], color="violet", align="center")
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# <font color=orange>
#
# ## 52. CONCLUSION / KEY FINDINGS / RECOMMENDATIONS
#
#
# ###### OBSERVATIONS:
#
# * <span style='color:#0e92ea'>Comparing Decision Trees and Random Forest as well as Adaboost, Gradient Boosting, and XGBoost:</span> <span style='color:darkblue'>The best R-squared value was 0.637</span>
#
# * <span style='color:#0e92ea'>Important Features:</span> <span style='color:darkblue'>Executive designation, having a passport, and Age were all the highest Gini importance score</span>
#
# * <span style='color:#0e92ea'>Target Customer:</span> <span style='color:darkblue'># "The ideal customer is a married male executive who holds a passport, is on a salary, and calls into the travel company himself to purchases a basic package."</span>
#
# * <span style='color:#0e92ea'>Final Recommendation:</span> <span style='color:darkblue'>In order for the "Visit With Us" travel package company to keep marketing cost lower, do not contact people at random and, instead, target potential customers in Tier 1 regions.  It really doesn't matter if the person is male or female (because they purchase at the same percentage rate), however its best to avoid freelancers while calling people who work at large businesses. "Visit With Us" sales team should focus on Executives who are in their mid 30s.  Married customers tend to vacation more, however single people also buy travel packages. Finally, it is best to keep initial telephone pitches to between 10-15 minutes with at least 3 followup calls.</span>
